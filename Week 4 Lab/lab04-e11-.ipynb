# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('air_data.csv')

data.values
print(data)
result = data.loc[:,"pm10 standard"]
plt.hist(result)

plt.ylabel('Frequency')
plt.xlabel('Count')
plt.title('1 Micrometer Particulate Frequency Data')

plt.show()



 
# Show the dataframe
result
# Out:
#             Time  pm10 standard  pm25 standard  pm100 env
# 0   1.707348e+09            8.0              0        0.0
# 1   1.707348e+09            8.0              0        0.0
# 2   1.707348e+09            8.0              0        0.0
# 3   1.707348e+09            8.0              0        0.0
# 4   1.707348e+09            8.0              0        0.0
# 5   1.707348e+09            8.0              0        0.0
# 6   1.707348e+09            6.0              0        0.0
# 7   1.707348e+09            6.0              0        0.0
# 8   1.707348e+09            6.0              0        0.0
# 9   1.707348e+09            2.0              0        0.0
# 10  1.707348e+09            2.0              0        0.0
# 11  1.707348e+09            2.0              0        0.0
# 12  1.707348e+09            2.0              0        0.0
# 13  1.707348e+09            2.0              0        0.0
# 14  1.707348e+09            2.0              0        0.0
# ...

# %%
data.values

result = data.loc[:,"pm25 standard"]
plt.hist(result)

plt.ylabel('Frequency')
plt.xlabel('Count')
plt.title('2.5 Micrometer Particulate Frequency Data')

plt.show()

# %%
data.values

result = data.loc[:,"pm100 env"]
plt.hist(result)

plt.ylabel('Frequency')
plt.xlabel('Count')
plt.title('10 Micrometer Particulate Frequency Data')

plt.show()
